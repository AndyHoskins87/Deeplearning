# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Andrew Hoskins**
# * career change to a Machine Learning Engineer

# %% [markdown]
# *I am interested in data science because it has so many possibilites to improve our lives.*

# %% [markdown]
# ### Say Hello World

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# <a href="www.IBM.com" target="Website">IBM</a>
#
# * One
# * Two
# * Three
#
# `Here is some code!`
